# %%
x = c(1,2,3,4,5,7,8)
y = c(0.1, 0.4, 0.43, 0.5, 0.65, 0.7, 0.87)

# %%
 coord = spline(x, y , n = 10*length(x), method = "hyman", xmin = min(x), xmax = max(x),  ties = mean)

# %%
plot(coord$x, coord$y, type="l");
# Out:
# plot without title
